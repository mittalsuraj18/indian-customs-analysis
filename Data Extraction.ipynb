# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("./9c3d4aca-98a8-430f-8a43-76937c116ae1_IndianCustoms-Imports.csv")

# %%
data
# Out:
#         unit_quantity_code location_state  customs_tariff_heading  \
# 0                      PCS      Tamilnadu                90184900
# 1                      PCS      Tamilnadu                90184900
# 2                      PCS      Tamilnadu                90184900
# 3                      PCS      Tamilnadu                90184900
# 4                      PCS      Tamilnadu                90184900
# 5                      PCS      Tamilnadu                90184900
# 6                      PCS      Tamilnadu                90184900
# 7                      PCS      Tamilnadu                90184900
# 8                      PCS      Tamilnadu                90184900
# 9                      PCS      Tamilnadu                90184900
# 10                     PCS      Tamilnadu                90184900
# 11                     PCS      Tamilnadu                90184900
# 12                     PCS      Tamilnadu                90184900
# ...

# %%
data.to_pickle("./data.pickle")

# %%
# Out:
# ...
# Description of unit_quantity_code
# count     1789000
# unique         49
# top           PCS
# freq       919861
# Name: unit_quantity_code, dtype: object
# ...
# Description of location_state
# count         1789000
# unique             20
# top       Maharashtra
# freq           652314
# Name: location_state, dtype: object
# ...
# Description of customs_tariff_heading
# count    1.789000e+06
# mean     7.268251e+07
# std      2.078682e+07
# min      1.019090e+06
# 25%      6.205200e+07
# 50%      8.443995e+07
# 75%      8.541100e+07
# max      9.804900e+07
# Name: customs_tariff_heading, dtype: float64
# ...
# Description of value_of_goods_in_rupees
# count    1.789000e+06
# mean     7.368538e+05
# std      2.494213e+07
# min      0.000000e+00
# 25%      3.407900e+03
# 50%      1.633514e+04
# 75%      9.351276e+04
# max      7.114458e+09
# Name: value_of_goods_in_rupees, dtype: float64
# ...
# Description of quantity_desc
# count     1784689
# unique         40
# top        PIECES
# freq       919861
# ...

# %%
# Out:
# 0            SWITZERLAND
# 1            SWITZERLAND
# 2            SWITZERLAND
# 3            SWITZERLAND
# 4            SWITZERLAND
# 5            SWITZERLAND
# 6            SWITZERLAND
# 7            SWITZERLAND
# 8            SWITZERLAND
# 9            SWITZERLAND
# 10           SWITZERLAND
# 11           SWITZERLAND
# 12           SWITZERLAND
# 13           SWITZERLAND
# 14           SWITZERLAND
# 15           SWITZERLAND
# 16           SWITZERLAND
# 17           SWITZERLAND
# 18           SWITZERLAND
# 19           SWITZERLAND
# 20                 JAPAN
# 21         UNITED STATES
# 22         UNITED STATES
# 23         UNITED STATES
# 24               ESTONIA
# 25               ESTONIA
# 26               ESTONIA
# 27               ESTONIA
# 28               ESTONIA
# 29               ESTONIA
#                ...
# 1788970            ITALY
# 1788971            ITALY
# 1788972            ITALY
# 1788973            ITALY
# 1788974            ITALY
# 1788975            ITALY
# ...
